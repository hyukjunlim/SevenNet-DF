# %% [markdown]
# <a href="https://colab.research.google.com/github/MDIL-SNU/sevennet_tutorial/blob/main/notebooks/SevenNet_finetune_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SevenNet tutorial: finetuning + python interactive
#
# ---
# This notebook is a python interactive tutorial for finetuning `SevenNet-0`.\
# It continues from `SevenNet_python_tutorial.ipynb`, but can be thought as an isolated tutorial also.
#
# We recommend using a GPU. If you're using Colab, go to:\
# [`Runtime`] → [`Change runtime type`] → [`T4 GPU`] → [`Save`]\
# You can use CPU, but it is very slow and you should change the code.
# [`'device': 'cuda'`] → [`'device': 'cpu'`]
#
# If you're using Colab, it may crash occasionally. If it does, try starting from the beginning or from the cell where it crashed. If that doesn’t work, go to: \
# [`Runtime`] → [`Disconnect and delete runtime`] → restart the tutorial
#
# If you want to learn more about SevenNet, please check the link below:
# - [paper](https://pubs.acs.org/doi/10.1021/acs.jctc.4c00190)
# - [SevenNet github](https://github.com/MDIL-SNU/SevenNet)

# %% [markdown]
# ## 0. Installation
# If SevenNet is not installed on your computer, let's install it.

# %%
# Install SevenNet
# !pip install sevenn

# If you want to check the SevenNet code, clone the repo.
# !git clone https://github.com/MDIL-SNU/SevenNet.git

import os
working_dir = os.getcwd() # save current path
# Out:
# Collecting sevenn
#   Downloading sevenn-0.10.3-py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 3.6 MB/s eta 0:00:00
# Collecting ase (from sevenn)
#   Downloading ase-3.23.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting braceexpand (from sevenn)
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from sevenn) (6.0.2)
# Collecting e3nn (from sevenn)
#   Downloading e3nn-0.5.4-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sevenn) (4.66.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sevenn) (1.5.2)
# Collecting torch_geometric>=2.5.0 (from sevenn)
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from sevenn) (1.26.4)
# Collecting matscipy (from sevenn)
#   Downloading matscipy-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (37 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch_geometric>=2.5.0->sevenn) (3.11.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch_geometric>=2.5.0->sevenn) (2024.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric>=2.5.0->sevenn) (3.1.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric>=2.5.0->sevenn) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric>=2.5.0->sevenn) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric>=2.5.0->sevenn) (2.32.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from ase->sevenn) (1.13.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.10/dist-packages (from ase->sevenn) (3.8.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from e3nn->sevenn) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from e3nn->sevenn) (2.5.1+cu121)
# Collecting opt-einsum-fx>=0.1.4 (from e3nn->sevenn)
#   Downloading opt_einsum_fx-0.1.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from matscipy->sevenn) (24.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sevenn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sevenn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->sevenn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->sevenn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->sevenn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->sevenn) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->sevenn) (11.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->sevenn) (2.8.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from opt-einsum-fx>=0.1.4->e3nn->sevenn) (3.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn->sevenn) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn->sevenn) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn->sevenn) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->e3nn->sevenn) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric>=2.5.0->sevenn) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric>=2.5.0->sevenn) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric>=2.5.0->sevenn) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric>=2.5.0->sevenn) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric>=2.5.0->sevenn) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric>=2.5.0->sevenn) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric>=2.5.0->sevenn) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric>=2.5.0->sevenn) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric>=2.5.0->sevenn) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric>=2.5.0->sevenn) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric>=2.5.0->sevenn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric>=2.5.0->sevenn) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric>=2.5.0->sevenn) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase->sevenn) (1.17.0)
# Downloading sevenn-0.10.3-py3-none-any.whl (42.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 14.8 MB/s eta 0:00:00
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.8 MB/s eta 0:00:00
# Downloading ase-3.23.0-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 51.1 MB/s eta 0:00:00
# Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Downloading e3nn-0.5.4-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.2/447.2 kB 16.2 MB/s eta 0:00:00
# Downloading matscipy-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (448 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.8/448.8 kB 19.7 MB/s eta 0:00:00
# Downloading opt_einsum_fx-0.1.4-py3-none-any.whl (13 kB)
# Installing collected packages: braceexpand, opt-einsum-fx, ase, torch_geometric, matscipy, e3nn, sevenn
# Successfully installed ase-3.23.0 braceexpand-0.1.7 e3nn-0.5.4 matscipy-1.1.1 opt-einsum-fx-0.1.4 sevenn-0.10.3 torch_geometric-2.6.1

# %%
# check if sevenn is installed well
import sevenn
sevenn.__version__
# Out:
# '0.10.3'

# %% [markdown]
# ## 1. Loading the model for fine-tuning
# In this tutorial, we will fine-tune the `SevenNet-0` model.\
# `SevenNet-0` is a pretrained machine learning potential, which is configured with `lmax = 2` and `num_convolution_layer = 5`, trained on the `MPtraj` dataset.
# Using `util`, we can easily load the `SevenNet-0` or the model that you want to fine-tune (using the path of the `checkpoint.pth` file).
#
# In this tutorial, for fast training speed, we'll use the different `shift` and `scale` module.

# %%
import sevenn.util as util
from sevenn.nn.scale import SpeciesWiseRescale
sevennet_0_cp_path = util.pretrained_name_to_path('7net-0')
model, config = util.model_from_checkpoint(sevennet_0_cp_path)

# To enhance training speed, we will overwrite shift scale module to trainable
# By making energy shift trainable, error quickly converges.
shift_scale_module = model._modules['rescale_atomic_energy']
shift = shift_scale_module.shift.tolist()
scale = shift_scale_module.scale.tolist()
model._modules['rescale_atomic_energy'] = SpeciesWiseRescale(
    shift=shift,
    scale=scale,
    train_shift_scale=True,
)
print(model)
# Out:
# AtomGraphSequential(
#   (edge_embedding): EdgeEmbedding(
#     (basis_function): BesselBasis()
#     (cutoff_function): XPLORCutoff()
#     (spherical): SphericalEncoding(
#       (sph): SphericalHarmonics()
#     )
#   )
#   (onehot_idx_to_onehot): OnehotEmbedding()
#   (onehot_to_feature_x): IrrepsLinear(
#     (linear): Linear(89x0e -> 128x0e | 11392 weights)
#   )
#   (0_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e -> 224x0e+64x1e+32x2e | 28672 weights)
#   )
#   (0_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e -> 128x0e | 16384 weights)
#   )
#   (0_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e x 1x0e+1x1e+1x2e -> 128x0e+128x1e+128x2e | 384 paths | 384 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 384]
#   )
#   (0_self_interaction_2): IrrepsLinear(
#     (linear): Linear(128x0e+128x1e+128x2e -> 224x0e+64x1e+32x2e | 40960 weights)
#   )
#   (0_self_connection_outro): SelfConnectionOutro()
#   (0_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (1_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 224x0e+64x1e+32x2e | 33792 weights)
#   )
#   (1_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (1_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e+384x1e+352x2e | 960 paths | 960 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 960]
#   )
#   (1_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e+384x1e+352x2e -> 224x0e+64x1e+32x2e | 86016 weights)
#   )
#   (1_self_connection_outro): SelfConnectionOutro()
#   (1_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (2_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 224x0e+64x1e+32x2e | 33792 weights)
#   )
#   (2_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (2_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e+384x1e+352x2e | 960 paths | 960 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 960]
#   )
#   (2_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e+384x1e+352x2e -> 224x0e+64x1e+32x2e | 86016 weights)
#   )
#   (2_self_connection_outro): SelfConnectionOutro()
#   (2_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (3_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 224x0e+64x1e+32x2e | 33792 weights)
#   )
#   (3_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (3_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e+384x1e+352x2e | 960 paths | 960 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 960]
#   )
#   (3_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e+384x1e+352x2e -> 224x0e+64x1e+32x2e | 86016 weights)
#   )
#   (3_self_connection_outro): SelfConnectionOutro()
#   (3_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (4_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e | 16384 weights)
#   )
#   (4_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (4_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e | 224 paths | 224 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 224]
#   )
#   (4_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e -> 128x0e | 28672 weights)
#   )
#   (4_self_connection_outro): SelfConnectionOutro()
#   (4_equivariant_gate): EquivariantGate(
#     (gate): Gate (128x0e -> 128x0e)
#   )
#   (reduce_input_to_hidden): IrrepsLinear(
#     (linear): Linear(128x0e -> 64x0e | 8192 weights)
#   )
#   (reduce_hidden_to_energy): IrrepsLinear(
#     (linear): Linear(64x0e -> 1x0e | 64 weights)
#   )
#   (rescale_atomic_energy): SpeciesWiseRescale()
#   (reduce_total_enegy): AtomReduce()
#   (force_output): ForceStressOutputFromEdge()
# )

# %% [markdown]
# ## 2. Dataset for fine-tuning
# We will use the same **Li-argyrodite (Li<sub>6</sub>PS<sub>5</sub>Cl)** data as in the previous python-interactive tutorial.
# ### Dataset download

# %%
import os.path

data_path = './data'
if not os.path.exists(data_path):
    # If you have this notebook file only, (or using colab) download the dataset
    # !git clone https://github.com/MDIL-SNU/sevennet_tutorial.git
    data_path = 'sevennet_tutorial/data'

assert os.path.exists(data_path) and os.path.exists(os.path.join(data_path, 'train'))
# Out:
# Cloning into 'sevennet_tutorial'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 107 (delta 42), reused 89 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 6.37 MiB | 20.98 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %% [markdown]
# ### Dataset setting
# Using `SevenNetGraphDataset`, we can easily generate graph data (**.pt**) from material data files like **POSCAR** or **extxyz**.\
# We prepared two extxyz files of Li-argyrodite trajectory at 600 K and 1200 K.\
# The cutoff radius of `SevenNet-0` is 5 Å, and that information is stored in the `config`, which is loaded through the `util`.\
# We have total 170 data, and each data has 416 nodes (Li<sub>192</sub>P<sub>32</sub>S<sub>160</sub>Cl<sub>32</sub>) and 11,254 edges (5 Å cutoff).

# %%
import os
from sevenn.train.graph_dataset import SevenNetGraphDataset

working_dir = os.getcwd() # change if you want
train_dir = os.path.join(data_path, 'train/')
xyz_files = ['1200K.extxyz', '600K.extxyz']
dataset_files = [os.path.join(train_dir, xyz) for xyz in xyz_files]

cutoff = config['cutoff']  # 7net-0 uses 5.0 Angstrom cutoff
# Preprocess(build graphs) data before training. It will automatically saves processed graph to {root}/sevenn_data/train.pt, metadata + statistics as train.yaml
# If you run below code on more time, it will load saved train.pt automatically instread of rebuilding graph.
# If you have changed your data for some reason, put 'force_reload=True' to reload dataset. Or put processed_name other than
dataset = SevenNetGraphDataset(cutoff=cutoff, root=working_dir, files=dataset_files, processed_name='train.pt')

print(f'# graphs: {len(dataset)}')
print(f'# atoms (nodes): {dataset.natoms}')
print(dataset[0])
# Out:
# Processing...
# graph_build (1): 100%|██████████| 85/85 [00:00<00:00, 112.05it/s]
# graph_build (1): 100%|██████████| 85/85 [00:00<00:00, 113.46it/s]
# run_stat: 100%|██████████| 170/170 [00:00<00:00, 973.79it/s]
# Done!
# # graphs: 170
# # atoms (nodes): {'Cl': 5440, 'Li': 32640, 'P': 5440, 'S': 27200, 'total': 70720}
# AtomGraphData(
#   x=[416],
#   edge_index=[2, 11254],
#   pos=[416, 3],
#   node_attr=[416],
#   atomic_numbers=[416],
#   edge_vec=[11254, 3],
#   total_energy=[1],
#   force_of_atoms=[416, 3],
#   stress=[1, 6],
#   cell_lattice_vectors=[3, 3],
#   pbc_shift=[11254, 3],
#   cell_volume=[1],
#   num_atoms=[1],
#   per_atom_energy=[1],
#   data_info={}
# )

# %% [markdown]
# Using `DataLoader` from `torch_geometric.loader`, we can make a dataloader for training.\
# This time, we'll use only 25 % of the total data for fine-tuning.

# %%
from torch_geometric.loader import DataLoader

# split the dataset into train & valid
# We will use only 25% of original dataset (from_scratch used 95% of it). For fine-tuning.
# Fine-tuning is significantly data efficient than from-scratch!
num_dataset = len(dataset)
num_train = int(num_dataset * 0.25)
num_valid = 10

dataset = dataset.shuffle()
train_dataset = dataset[:num_train]
valid_dataset = dataset[num_train:num_train + 10]

print(f'# graphs for training: {len(train_dataset)}')
print(f'# graphs for validation: {len(valid_dataset)}')

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=4)
# Out:
# # graphs for training: 42
# # graphs for validation: 10

# %% [markdown]
# ## 3. Fine-tuning
# ### Training setting
# Before fine-tuning, we need to set the up the training settings.\
# We can update the parameters in `config` loaded through the `util`.\
# We should make `'is_ddp': False` because we'll just use a single GPU for fine-tuning.

# %%
from sevenn.train.trainer import Trainer
import torch.optim.lr_scheduler as scheduler

config.update({
    'optimizer': 'adam',
    'optim_param': {'lr': 0.004},
    'scheduler': 'linearlr',
    'scheduler_param': {'start_factor': 1.0, 'total_iters': 10, 'end_factor': 0.0001},
    'is_ddp': False,  # 7net-0 is traied with ddp=True. We override this key False as we won't use it
})
trainer = Trainer.from_config(model, config)

# We have energy, force, stress loss function, which used to train 7net-0.
# We will use it as it is, with loss weight: 1.0, 1.0, and 0.01 for energy, force, and stress, respectively.
print(trainer.loss_functions)
print(trainer.optimizer)
print(trainer.scheduler)
# Out:
# [(Energy, 1.0), (Force, 1.0), (Stress, 0.01)]
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.004
#     lr: 0.004
#     maximize: False
#     weight_decay: 0
# )
# <torch.optim.lr_scheduler.LinearLR object at 0x7dca01f03ca0>

# %% [markdown]
# To track changes in loss during training, we can use `ErrorRecorder`.

# %%
from copy import deepcopy
from sevenn.error_recorder import ErrorRecorder

train_recorder = ErrorRecorder.from_config(config)
valid_recorder = deepcopy(train_recorder)
for metric in train_recorder.metrics:
  print(metric)
# Out:
# Energy_RMSE (eV/atom): nan
# Force_RMSE (eV/Å): nan
# Stress_RMSE (kbar): nan
# Energy_MAE (eV/atom): nan
# Force_MAE (eV/Å): nan
# Stress_MAE (kbar): nan
# Energy_Loss: nan
# Force_Loss: nan
# Stress_Loss: nan
# TotalLoss: nan

# %% [markdown]
# ### Training start!
# Let's start the fine-tuning!\
# Using `Trainer` and `ErrorRecorder`, we can easily perform training.
# Also, using `Logger`, we can easily print the training log.

# %%
from sevenn.sevenn_logger import Logger

valid_best = float('inf')
total_epoch = 10

logger = Logger()
logger.screen = True

# As error recorder is long, let's use sevennet_logger for pretty print
# It is similar to outputs when using sevennet with terminal.
with logger:
    logger.greeting()  # prints ascii logo
    for epoch in range(1, total_epoch + 1):  # ~ 16 sec/epoch with RTX4060
        logger.timer_start('epoch')
        logger.writeline(f'Epoch {epoch}/{total_epoch}  Learning rate: {trainer.get_lr():.6f}')
        # trainer scans whole data from given loader, and updates error recorder with outputs.
        trainer.run_one_epoch(train_loader, is_train=True, error_recorder=train_recorder)
        trainer.run_one_epoch(valid_loader, is_train=False, error_recorder=valid_recorder)
        trainer.scheduler_step()
        train_err = train_recorder.epoch_forward()  # return averaged error over one epoch, then reset.
        valid_err = valid_recorder.epoch_forward()
        logger.bar()
        logger.write_full_table([train_err, valid_err], ['Train', 'Valid'])
        logger.timer_end('epoch', message=f'Epoch {epoch} elapsed')

trainer.write_checkpoint(os.path.join(working_dir, 'checkpoint_fine_tuned.pth'), config=config, epoch=total_epoch)
# Out:
# SevenNet: Scalable EquVariance-Enabled Neural Network
# version 0.10.3, Mon Dec 16 15:56:02 2024
# this file: None
# reading yaml config...
#                 ****
#               ********                                   .
#               *//////,  ..                               .            ,*.
#                ,,***.         ..                        ,          ********.                                  ./,
#              .      .                ..   /////.       .,       . */////////                               /////////.
#         .&@&/        .                  .(((((((..     /           *//////*.  ...                         *((((((((((.
#      @@@@@@@@@@*    @@@@@@@@@@  @@@@@    *((@@@@@     (     %@@@@@@@@@@  .@@@@@@     ..@@@@.   @@@@@@*    .(@@@@@(((*
#     @@@@@.          @@@@         @@@@@ .   @@@@@      #     %@@@@         @@@@@@@@     @@@@(,  @@@@@@@@.    @@@@@(*.
#     %@@@@@@@&       @@@@@@@@@@    @@@@@   @@@@@      #  ., .%@@@@@@@@@    @@@@@@@@@@   @@@@,   @@@@@@@@@@   @@@@@
#     ,(%@@@@@@@@@    @@@@@@@@@@     @@@@@ @@@@&       (//////%@@@@@@@@@    @@@@  @@@@@@ @@@@  . @@@@@  @@@@@.@@@@@
#         .   @@@@@   @@@@ .       .  @@@@@@@@%   . . ( .////,%@@@@         @@@@    @@@@@@@@@    @@@@@    @@@@@@@@@
#     (@@@@@@@@@@@    @@@@@@@@@@**.    @@@@@@*       *.      .%@@@@@@@@@@   @@@@    . @@@@@@@    @@@@@     .@@@@@@@
#      @@@@@@@@@.     @@@@@@@@@@///,    @@@@.      . /        %@@@@@@@@@@   @@@@***,    @@@@@    @@@@@        @@@@@
#            .           //////////*.               /           .            .*******...             . ,.
#           .&&&&&...     ,//////*.       ...////.  /            ,*/.     .   ,////,               .,/////
#           &@@@@@@                         ,(/((, *           ,((((((.                              .***.
#            ,/@(,                            ..   *            ,((((*
#                                                 ,
#                                                .
# Epoch 1/10  Learning rate: 0.004000
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   Stress_RMSE (kbar)   Energy_MAE (eV/atom)   Force_MAE (eV/Å)   Stress_MAE (kbar)   Energy_Loss   Force_Loss   Stress_Loss   TotalLoss
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train               0.089282            0.231782            14.533902               0.078868           0.094464            3.096323      0.000708     0.000887      0.029876    0.001894
# Valid               0.051989            0.205825             5.009277               0.051930           0.088668            1.445064      0.000472     0.000822      0.014826    0.001442
# Epoch 1 elapsed: 0:00:27.64
# Epoch 2/10  Learning rate: 0.003600
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   Stress_RMSE (kbar)   Energy_MAE (eV/atom)   Force_MAE (eV/Å)   Stress_MAE (kbar)   Energy_Loss   Force_Loss   Stress_Loss   TotalLoss
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train               0.044032            0.186021             5.007697               0.039813           0.078816            1.320439      0.000339     0.000736      0.012923    0.001204
# Valid               0.005802            0.153996             2.365347               0.005280           0.063236            0.700905      0.000017     0.000569      0.006874    0.000655
# Epoch 2 elapsed: 0:00:19.12
# Epoch 3/10  Learning rate: 0.003200
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   Stress_RMSE (kbar)   Energy_MAE (eV/atom)   Force_MAE (eV/Å)   Stress_MAE (kbar)   Energy_Loss   Force_Loss   Stress_Loss   TotalLoss
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train               0.011294            0.150407             1.780804               0.009998           0.063695            0.511725      0.000054     0.000591      0.005022    0.000696
# Valid               0.007334            0.128597             4.161370               0.007165           0.054078            1.247010      0.000026     0.000481      0.012484    0.000632
# Epoch 3 elapsed: 0:00:19.14
# Epoch 4/10  Learning rate: 0.002800
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   Stress_RMSE (kbar)   Energy_MAE (eV/atom)   Force_MAE (eV/Å)   Stress_MAE (kbar)   Energy_Loss   Force_Loss   Stress_Loss   TotalLoss
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train               0.006837            0.130255             2.347135               0.006273           0.054647            0.644436      0.000023     0.000498      0.006529    0.000587
# Valid               0.003330            0.114404             0.914728               0.003187           0.047670            0.276751      0.000006     0.000418      0.002621    0.000450
# Epoch 4 elapsed: 0:00:19.03
# Epoch 5/10  Learning rate: 0.002400
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   Stress_RMSE (kbar)   Energy_MAE (eV/atom)   Force_MAE (eV/Å)   Stress_MAE (kbar)   Energy_Loss   Force_Loss   Stress_Loss   TotalLoss
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train               0.004163            0.119887             3.044597               0.003719           0.049868            0.848598      0.000009     0.000451      0.008485    0.000545
# Valid               0.005422            0.108400             3.311452               0.005361           0.044547            1.013872      0.000015     0.000387      0.009920    0.000501
# Epoch 5 elapsed: 0:00:19.08
# Epoch 6/10  Learning rate: 0.002000
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   Stress_RMSE (kbar)   Energy_MAE (eV/atom)   Force_MAE (eV/Å)   Stress_MAE (kbar)   Energy_Loss   Force_Loss   Stress_Loss   TotalLoss
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train               0.003321            0.112087             2.249380               0.002849           0.046190            0.674432      0.000005     0.000414      0.006567    0.000485
# Valid               0.001119            0.103920             2.722929               0.001027           0.042544            0.837081      0.000001     0.000368      0.008183    0.000450
# Epoch 6 elapsed: 0:00:19.19
# Epoch 7/10  Learning rate: 0.001600
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   Stress_RMSE (kbar)   Energy_MAE (eV/atom)   Force_MAE (eV/Å)   Stress_MAE (kbar)   Energy_Loss   Force_Loss   Stress_Loss   TotalLoss
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train               0.001399            0.107685             1.866737               0.001213           0.044093            0.539349      0.000001     0.000389      0.005238    0.000442
# Valid               0.001394            0.100647             0.862887               0.001027           0.040958            0.257593      0.000001     0.000352      0.002406    0.000377
# Epoch 7 elapsed: 0:00:19.37
# Epoch 8/10  Learning rate: 0.001200
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   Stress_RMSE (kbar)   Energy_MAE (eV/atom)   Force_MAE (eV/Å)   Stress_MAE (kbar)   Energy_Loss   Force_Loss   Stress_Loss   TotalLoss
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train               0.001177            0.104260             0.917673               0.000896           0.042562            0.282794      0.000001     0.000378      0.002799    0.000407
# Valid               0.001030            0.098328             0.795078               0.000704           0.039908            0.246253      0.000000     0.000342      0.002399    0.000367
# Epoch 8 elapsed: 0:00:19.32
# Epoch 9/10  Learning rate: 0.000800
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   Stress_RMSE (kbar)   Energy_MAE (eV/atom)   Force_MAE (eV/Å)   Stress_MAE (kbar)   Energy_Loss   Force_Loss   Stress_Loss   TotalLoss
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train               0.000828            0.102306             0.760679               0.000688           0.041701            0.235093      0.000000     0.000366      0.002310    0.000389
# Valid               0.000914            0.097423             0.860286               0.000743           0.039446            0.255587      0.000000     0.000338      0.002363    0.000362
# Epoch 9 elapsed: 0:00:19.35
# Epoch 10/10  Learning rate: 0.000400
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   Stress_RMSE (kbar)   Energy_MAE (eV/atom)   Force_MAE (eV/Å)   Stress_MAE (kbar)   Energy_Loss   Force_Loss   Stress_Loss   TotalLoss
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train               0.000793            0.101197             0.697143               0.000710           0.041191            0.219496      0.000000     0.000365      0.002159    0.000387
# Valid               0.000920            0.096645             0.883092               0.000666           0.039145            0.262116      0.000000     0.000335      0.002617    0.000361
# Epoch 10 elapsed: 0:00:19.40

# %% [markdown]
# ## 4. Model test
# ### Energy / force plot
# Let's predict the energy and force of test dataset and draw the parity plots.\
# Using `SevenNetCalculator`, we can load the checkpoint of the model we've trained to calculate the energy and forces.\
# Comparing the `SevenNet-0` and the `fine-tuned` model, fine-tuning with just 42 data samples for 10 epochs, the `fine-tuned` model shows significantly improved accuracy in predicting energy and forces.

# %%
# load test model
import os
working_dir = './'

# If you have this notebook file only, (or using colab) download the dataset
# !git clone https://github.com/MDIL-SNU/sevennet_tutorial.git
data_path = 'sevennet_tutorial/data'

# If you have downloaded git repository (sevennet_tutorial), set data path
# data_path = './data'
assert os.path.exists(data_path) and os.path.exists(os.path.join(data_path, 'evaluation'))

import torch
import ase.io

from sevenn.sevennet_calculator import SevenNetCalculator

# Let's test our model by predicting DFT MD trajectory
# Instead of using other functions in SevenNet, we will use ASE calculator as an interface of our model
DFT_md_xyz = os.path.join(data_path, 'evaluation/test_md.extxyz')

# initialize calculator from checkpoint.
fine_tuned_calc = SevenNetCalculator(os.path.join(working_dir, 'checkpoint_fine_tuned.pth'))
sevennet_0_calc = SevenNetCalculator('7net-0')  # As a baseline

# load DFT md trajectory
traj = ase.io.read(DFT_md_xyz, index=':')

# %%
import numpy as np
from tqdm import tqdm

dft_energy, dft_forces, dft_stress = [], [], []
ft_energy, ft_forces, ft_stress = [], [], []
base_energy, base_forces, base_stress = [], [], []
to_kBar = 1602.1766208

for atoms in tqdm(traj):
  atoms.calc = fine_tuned_calc
  ft_energy.append(atoms.get_potential_energy() / len(atoms))  # as per atom energy
  ft_forces.append(atoms.get_forces())
  ft_stress.extend(-1 * atoms.get_stress() * to_kBar)  # eV/Angstrom^3 to kBar unit

  atoms.calc = sevennet_0_calc
  base_energy.append(atoms.get_potential_energy() / len(atoms))  # as per atom energy
  base_forces.append(atoms.get_forces())
  base_stress.extend(-1 * atoms.get_stress() * to_kBar)

  dft_energy.append(atoms.info['DFT_energy'] / len(atoms))
  dft_forces.append(atoms.arrays['DFT_forces'])
  dft_stress.append(-1 * atoms.info['DFT_stress'] * to_kBar)
# Out:
# 100%|██████████| 100/100 [00:33<00:00,  3.00it/s]

# %%
# flatten forces and stress for parity plot
ft_forces = np.concatenate([f.reshape(-1,) for f in ft_forces])
ft_stress = np.concatenate([s.reshape(-1,) for s in ft_stress])

base_forces = np.concatenate([f.reshape(-1,) for f in base_forces])
base_stress = np.concatenate([s.reshape(-1,) for s in base_stress])

dft_forces = np.concatenate([f.reshape(-1,) for f in dft_forces])
dft_stress = np.concatenate([s.reshape(-1,) for s in dft_stress])

# %%
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# draw a parity plot of energy / force / stress
unit = {"energy": "eV/atom", "force": r"eV/$\rm{\AA}$", "stress": "kbar"}
def density_colored_scatter_plot(dft_energy, nnp_energy, dft_force, nnp_force, dft_stress, nnp_stress, title=None):
    modes = ['energy', 'force', 'stress']
    plt.figure(figsize=(18/2.54, 6/2.54))
    for num, (x, y) in enumerate(zip([dft_energy, dft_force, dft_stress], [nnp_energy, nnp_force, nnp_stress])):
        mode = modes[num]
        idx = np.random.choice(len(x), 1000) if len(x) > 1000 else list(range(len(x)))
        xsam = [x[i] for i in idx]
        ysam = [y[i] for i in idx]
        xy = np.vstack([x, y])
        xysam = np.vstack([xsam, ysam])
        zsam = gaussian_kde(xysam)

        z = zsam.pdf(xy)
        idx = z.argsort()

        x = [x[i] for i in idx]
        y = [y[i] for i in idx]
        z = [z[i] for i in idx]

        ax = plt.subplot(int(f'13{num+1}'))
        plt.scatter(x, y, c=z, s=4, cmap='plasma')

        mini = min(min(x), min(y))
        maxi = max(max(x), max(y))
        ran = (maxi-mini) / 20
        plt.plot([mini-ran, maxi+ran], [mini-ran, maxi+ran], color='grey', linestyle='dashed')
        plt.xlim(mini-ran, maxi+ran)
        plt.ylim(mini-ran, maxi+ran)

        plt.xlabel(f'DFT {mode} ({unit[mode]})')
        plt.ylabel(f'MLP {mode} ({unit[mode]})')
        ax.set_aspect('equal')
        if title:
          ax.set_title(f'{title} {mode}')
    plt.tight_layout()
    plt.show()

density_colored_scatter_plot(dft_energy, base_energy, dft_forces, base_forces, dft_stress, base_stress, '7net-0')
density_colored_scatter_plot(dft_energy, ft_energy, dft_forces, ft_forces, dft_stress, ft_stress, 'fine-tuned')

# %% [markdown]
# ## ASE relaxation & Drawing an EOS curve
# Additionally, you can use the trained model to perform structure relaxation and plot the EOS curve.\
# The result of `SevenNet-0` is decent, but the `fine-tuned` model's EOS aligns more closely with DFT.

# %%
import warnings
warnings.filterwarnings("ignore")

from ase.constraints import UnitCellFilter
from ase.optimize import LBFGS
from ase.calculators.singlepoint import SinglePointCalculator

# codes for drawing EOS curve

def atom_oneshot(atoms, calc):
    energy = atoms.get_potential_energy()
    forces = atoms.get_forces()
    stress = atoms.get_stress()

    calc_results = {"energy": energy, "forces": forces, "stress": stress}
    calculator = SinglePointCalculator(atoms, **calc_results)
    atoms = calculator.get_atoms()

    return atoms

def atom_cell_relax(atoms, calc, logfile="-"):
    atoms.calc = calc
    cf = UnitCellFilter(atoms, hydrostatic_strain=True)
    opt = LBFGS(cf, logfile=logfile)
    opt.run(fmax=0.02, steps=1000)

    return atoms

def make_eos_structures(relaxed):
    relaxed_cell = relaxed.get_cell()
    relaxed_lat = relaxed_cell.lengths()[0]

    eos_structures = []
    for strain in np.linspace(-0.05, 0.05, 11):
        strained_lat = relaxed_lat * (1+strain)
        relaxed.set_cell([strained_lat]*3, scale_atoms=True)
        eos_structures.append(deepcopy(relaxed))

    return eos_structures

def get_eos_and_volume(eos_list):
    en_list = []
    vol_list = []
    for atoms in eos_list:
        en_list.append(atoms.get_potential_energy())
        vol_list.append(atoms.get_volume())

    rel_en_list = np.array(en_list) - min(en_list)

    return rel_en_list, vol_list

# %%
# calculate EOS curve
import os
from tqdm import tqdm
from copy import deepcopy
import numpy as np
from ase.io import read, write
from sevenn.sevennet_calculator import SevenNetCalculator

os.makedirs('eos', exist_ok=True)
atoms_list = read(os.path.join(data_path, 'evaluation/eos.extxyz'), ':')  # most stable structure idx
most_stable_idx = np.argmin([at.get_potential_energy() for at in atoms_list])
print(f"(DFT) potential_energy (eV/atom): {atoms_list[most_stable_idx].get_potential_energy() / len(atoms_list[0])}")
atoms = atoms_list[most_stable_idx]

log_path = './eos/seven_relax_log.txt'
print("Relax with fine-tuned potential...")
ft_relaxed = atom_cell_relax(deepcopy(atoms), fine_tuned_calc, './eos/ft_relax_log.txt')
print(f"(FT) potential_energy (eV/atom): {ft_relaxed.get_potential_energy() / len(ft_relaxed)}")

print("Relax with sevennet-0 potential...")
base_relaxed = atom_cell_relax(deepcopy(atoms), sevennet_0_calc, './eos/sevenet_0_relax_log.txt')
print(f"(7net-0) potential_energy (eV/atom): {base_relaxed.get_potential_energy() / len(base_relaxed)}")

ft_eos_structures = make_eos_structures(ft_relaxed)
base_eos_structures = make_eos_structures(base_relaxed)
ft_eos_oneshot = []
base_eos_oneshot = []
for ft_stct, base_stct in tqdm(zip(ft_eos_structures, base_eos_structures), desc="Compute energy for each structures", total=len(ft_eos_structures)):
    ft_eos_oneshot.append(atom_oneshot(ft_stct, fine_tuned_calc))
    base_eos_oneshot.append(atom_oneshot(base_stct, sevennet_0_calc))

write('./eos/ft_eos.extxyz', ft_eos_oneshot)
write('./eos/base_eos.extxyz', base_eos_oneshot)
# Out:
# (DFT) potential_energy (eV/atom): -4.166412019230769
# Relax with fine-tuned potential...
# (FT) potential_energy (eV/atom): -4.165822542630709
# Relax with sevennet-0 potential...
# (7net-0) potential_energy (eV/atom): -4.168001615084135
# Compute energy for each structures: 100%|██████████| 11/11 [00:06<00:00,  1.59it/s]

# %%
# draw EOS curve and compare with DFT
dft_eos, dft_vol = get_eos_and_volume( read(os.path.join(data_path, 'evaluation/eos.extxyz'), ':'))
ft_eos, ft_vol = get_eos_and_volume(read('./eos/ft_eos.extxyz', ':'))
base_eos, base_vol = get_eos_and_volume(read('./eos/base_eos.extxyz', ':'))

plt.figure(figsize=(10/2.54, 8/2.54))
plt.plot(dft_vol, dft_eos, label='DFT')
plt.plot(ft_vol, ft_eos, label='Fine-tuned')
plt.plot(base_vol, base_eos, label='SevenNet-0')

plt.xlabel(r"Volume ($\rm{\AA}^3$)")
plt.ylabel("Relative energy (eV)")

plt.legend()
plt.tight_layout()
plt.show()
